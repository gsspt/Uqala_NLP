# %% [markdown]
# # 03 — Comparaison des pipelines
#
# Ce notebook compare les performances de tous les pipelines implémentés
# sur un même corpus de test (20% du corpus annoté).
#
# **Métriques** : Précision, Rappel, F1, AUC, temps d'inférence
#
# **Pipelines à comparer** :
# - P1.1 Règles booléennes
# - P1.2 Arbre de décision
# - P1.3 Régression logistique ✅
# - P2.1 XGBoost + SHAP ✅
# - A1 Cascade conservative ✅
# - C1 Active learning (après implémentation)
# - ...

# %%
# TODO : Implémenter après avoir plusieurs pipelines disponibles
print('À implémenter — voir pipelines/README.md pour le tableau de comparaison')
