# %% [markdown]
# # 01 — Exploration du corpus positif
#
# Ce notebook analyse les khabars 161-612 du *Kitāb ʿUqalāʾ al-Maǧānīn* (Nīsābūrī)
# pour comprendre la distribution des features caractéristiques du motif maǧnūn ʿāqil.
#
# **Objectifs** :
# 1. Distribution des genres (khabar, nadira, šiʿr)
# 2. Fréquence des noms propres de fous canoniques
# 3. Rôle de la poésie dans le motif
# 4. Distribution des longueurs de texte
# 5. Co-occurrences junūn × ʿaql

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Charger le corpus annoté
DATA = Path('../data/annotated/Kitab_Uqala_al_Majanin_annotated.json')
with open(DATA, encoding='utf-8') as f:
    corpus = json.load(f)

print(f'{len(corpus)} khabars chargés')

# %% [markdown]
# ## TODO : Implémenter les analyses
#
# Voir `scripts/discover_features.py` pour le pipeline de découverte inductive.
